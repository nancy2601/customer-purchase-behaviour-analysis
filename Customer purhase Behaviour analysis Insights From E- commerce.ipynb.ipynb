# %%
# 🛍️ Customer Purchase Behavior Analysis – Retail Dataset

### 📌 Project Objective:
#To analyze customer purchase behavior using a retail dataset to uncover trends, segment customers, and generate business insights that can improve sales strategy and customer retention.

### 🧩 Business Context:
#Consulting firms like Accenture and Deloitte help retail clients understand consumer patterns, optimize product offerings, and reduce churn. This analysis simulates the kind of business intelligence work expected from a professional Data Analyst.



### 🧪 Tools Used:
#- **Python**
#- **Pandas & NumPy** – Data cleaning & wrangling
#- **Seaborn & Matplotlib** – Visualizations
#- **Jupyter Notebook** – Workflow documentation

# %%
import pandas as pd

# Load the pre-generated dataset
df = pd.read_csv("Correct_Ecommerce_Retail_Dataset.csv")

# Convert InvoiceDate column to datetime
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
## 🔍 Step 4: Exploratory Data Analysis (EDA)

#We will now explore the dataset to uncover customer behavior patterns, product sales trends, and revenue breakdowns. 
#This will help generate insights to inform business strategy and optimize customer targeting.

# %%
#total revenue 
total_revenue = df["TotalPrice"].sum()
print(f"💰 Total Revenue Generated: ₹{total_revenue:,.2f}")
# Out:
# 💰 Total Revenue Generated: ₹2,630,515.99

# %%
##Top 10 Selling Products (by Revenue)
top_products = (
    df.groupby("Description")["TotalPrice"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

top_products.plot(kind='bar', figsize=(10,5), color='skyblue')
plt.title("Top 10 Products by Revenue")
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# revenue by country 
revenue_country = (
    df.groupby("Country")["TotalPrice"]
    .sum()
    .sort_values(ascending=False)
)

revenue_country.plot(kind='bar', figsize=(10,5), color='salmon')
plt.title("Revenue by Country")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# monthly sales trend
df['Month'] = df['InvoiceDate'].dt.to_period('M')
monthly_sales = df.groupby("Month")["TotalPrice"].sum()

monthly_sales.plot(kind='line', marker='o', figsize=(10,4), color='green')
plt.title("Monthly Sales Trend")
plt.ylabel("Revenue")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
## no. of unique customers 
num_customers = df["CustomerID"].nunique()
print(f"🧍 Unique Customers: {num_customers}")
# Out:
# 🧍 Unique Customers: 200

# %%
#Average Basket Size (Revenue per Transaction)
avg_basket = df.groupby("InvoiceNo")["TotalPrice"].sum().mean()
print(f"🛒 Avg Basket Value per Transaction: ₹{avg_basket:,.2f}")
# Out:
# 🛒 Avg Basket Value per Transaction: ₹275.27

# %%
### 💡 Step 5: Key Insights & Business Recommendations

### 🔍 Insights:
1. **Top-Selling Products:** Products like "Shoes" and "T-shirt" drive the majority of revenue. These should be stocked more frequently and promoted during high-traffic periods.
2. **High-Value Countries:** The United Kingdom generates the most revenue. Regional campaigns in the UK can help boost loyal customer engagement.
3. **Monthly Trends:** Revenue trends show consistent growth. Strategic promotions during low-performing months can help smooth out sales.
4. **Customer Base:** With over 100 unique customers, loyalty campaigns (e.g., coupons, memberships) can help increase repeat purchases.
5. **Average Basket Size:** Customers spend an average of ₹275.27 per order, indicating potential for upselling strategies using bundled offers.

### 📈 Business Recommendations:
- Run **targeted campaigns** focused on top 3 products.
- Launch a **UK-focused loyalty program** to retain high-value customers.
- Introduce **monthly discounts** during lower-performing months to stabilize sales.
- Monitor **customer basket sizes** and test product bundling.

# %%
#### 🧾 Step 6: Project Summary

This project simulates a real-world retail analytics problem. Using Python and core data analysis libraries, we explored customer purchase patterns, sales performance, and revenue trends. Visualizations and statistics helped derive meaningful insights that would guide business decisions in a consulting scenario.

---

### ✅ Skills Demonstrated:
- Data Cleaning & Preparation
- Exploratory Data Analysis (EDA)
- Data Aggregation and Grouping
- Business Insight Generation
- Data Visualization with Matplotlib & Seaborn



### 📌 Resume Line:
#**“Built an end-to-end E-Commerce Customer Purchase Analysis project using Python (pandas, seaborn, matplotlib), uncovering product, region, and time-based trends to drive strategic retail decisions — aligned with consulting use cases at Accenture & Deloitte.”**
